# %% [markdown]
# #### : Harmful Content Detection

# %% [markdown]
# #### Objective
# ##### The objective of this module is to develop a machine learning model that automatically detects harmful content from user-generated text. The model classifies text into predefined harmful content categories, helping government organizations identify abusive, offensive, or unsafe content and take timely moderation actions.

# %% [markdown]
# #### Importance of This Module
# Harmful Content Detection plays a vital role in maintaining a safe and respectful online environment. It enables government agencies and social media monitoring systems to detect toxic, abusive, hateful, or offensive content automatically, reducing the spread of harmful information and improving public trust in digital platforms.

# %% [markdown]
# #### Contribution to the Project
# This module contributes to the Government Social Media Analytics project by identifying harmful user comments and classifying them into appropriate categories. The insights generated from this module support content moderation, citizen safety, policy enforcement, and faster decision-making for handling inappropriate online content.

# %% [markdown]
# #### Dataset Description
#
# ##### Dataset Name: harmful_content
# This dataset contains user-generated text collected from online platforms along with corresponding harmful content labels. Each record consists of a text message and its associated category indicating whether the content is harmful or belongs to a specific harmful content class. The dataset is designed for supervised machine learning and text classification tasks.

# %% [markdown]
# #### Why this Dataset?
# This dataset was selected because it contains labeled text samples suitable for harmful content classification. It provides real-world examples of user-generated content, making it useful for training machine learning models to automatically identify harmful or non-harmful text. The dataset supports Natural Language Processing (NLP) techniques and helps build an effective text classification system.

# %% [markdown]
# #### Features (X) and Target Variable (Y)
# Input Feature (X)
#
# The primary input feature used for model training is:
#
# *text
#
# The text column contains user-generated comments, posts, or messages that will be analyzed by the machine learning model.

# %% [markdown]
# #### Target Variable (Y)
#
# The target variable is:
# label
#
# The label column represents the harmful content category assigned to each text. The machine learning model learns patterns from the text and predicts the correct harmful content class.

# %% [markdown]
# #### Machine Learning Problem Type
#
# Problem Type: Text Classification
#
# Since the target variable contains categories (labels) rather than numerical values, this module is a Supervised Machine Learning Classification problem.

# %% [markdown]
# ## 1: Dataset Loading
# ## 2: Harmful Content Detection
# ## 3: Feature Engineering
# ## 4: Harmful Content Model Preparation (Train-Test Split)
# ## 5: Model Building
# ## 6: Model Evaluation
# ## 7: Model Comparison
# ## 8: Model Saving and Prediction
# ## 9: Project Conclusion
# ## 10: Final Project Conclusion and Future Scope

# %% [markdown]
# #### Load Dataset from MySQL

# %% [markdown]
# ### step 1: Dataset Loading

# %%
import pandas as pd

df = pd.read_csv("Final_Harmful_Content_Dataset.csv")

print(df.head())
print(df.columns)
print(df.shape)
# Out:
#       text_id                                               text task_1  \
# 0  hasoc_en_1  dhonikeepstheglove  watch sports minister kire...    NOT
# 1  hasoc_en_2  politico no we should remember very clearly th...    HOF
# 2  hasoc_en_3  cricketworldcup guess who would be the winner ...    NOT
# 3  hasoc_en_4  corbyn is too politically intellectual for bor...    NOT
# 4  hasoc_en_5  all the best to teamindia for another swimming...    NOT
#
#   task_2 task_3  text_length  task_1_encoded
# 0   NONE   NONE          229               1
# 1   HATE    TIN          129               0
# 2   NONE   NONE          141               1
# 3   NONE   NONE          119               1
# 4   NONE   NONE          140               1
# Index(['text_id', 'text', 'task_1', 'task_2', 'task_3', 'text_length',
#        'task_1_encoded'],
#       dtype='object')
# (5852, 7)

# %%
print(df.columns.tolist())
# Out:
# ['text_id', 'text', 'task_1', 'task_2', 'task_3', 'text_length', 'task_1_encoded']

# %%
import pandas as pd

df = pd.read_csv("Final_Harmful_Content_Dataset.csv")

print(df.head())
print(df.columns)
print(df.shape)
# Out:
#       text_id                                               text task_1  \
# 0  hasoc_en_1  dhonikeepstheglove  watch sports minister kire...    NOT
# 1  hasoc_en_2  politico no we should remember very clearly th...    HOF
# 2  hasoc_en_3  cricketworldcup guess who would be the winner ...    NOT
# 3  hasoc_en_4  corbyn is too politically intellectual for bor...    NOT
# 4  hasoc_en_5  all the best to teamindia for another swimming...    NOT
#
#   task_2 task_3  text_length  task_1_encoded
# 0   NONE   NONE          229               1
# 1   HATE    TIN          129               0
# 2   NONE   NONE          141               1
# 3   NONE   NONE          119               1
# 4   NONE   NONE          140               1
# Index(['text_id', 'text', 'task_1', 'task_2', 'task_3', 'text_length',
#        'task_1_encoded'],
#       dtype='object')
# (5852, 7)

# %%
# ==========================================
# Step 3: Define Features and Target
# ==========================================

X_text = df["text"].fillna("").astype(str)

y = df["task_1_encoded"]

print("Total Samples :", len(X_text))
print("Total Labels  :", len(y))
# Out:
# Total Samples : 5852
# Total Labels  : 5852

# %%
# ==========================================
# Step 4: Train Test Split
# ==========================================

from sklearn.model_selection import train_test_split

X_train_text, X_test_text, y_train, y_test = train_test_split(
    X_text,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training Samples :", len(X_train_text))
print("Testing Samples  :", len(X_test_text))
# Out:
# Training Samples : 4681
# Testing Samples  : 1171

# %%
# ==========================================
# Step 5: Build Pipeline
# ==========================================

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

pipeline = Pipeline([
    (
        "tfidf",
        TfidfVectorizer(
            max_features=5000,
            stop_words="english",
            ngram_range=(1,2),
            min_df=2,
            max_df=0.95,
            sublinear_tf=True
        )
    ),
    (
        "classifier",
        LogisticRegression(
            max_iter=3000,
            random_state=42
        )
    )
])

print("Pipeline Created Successfully!")
# Out:
# Pipeline Created Successfully!

# %%
# ==========================================
# Step 6: Train Model
# ==========================================

pipeline.fit(X_train_text, y_train)

print("Pipeline Trained Successfully!")
# Out:
# Pipeline Trained Successfully!

# %%
# ==========================================
# Step 7: Save Model
# ==========================================

import joblib

joblib.dump(pipeline, "harmful_content_prediction_model.pkl")

print("Pipeline Saved Successfully!")
# Out:
# Pipeline Saved Successfully!

# %%
# ==========================================
# Step 8: Predict Single Text
# ==========================================

import joblib

model = joblib.load("harmful_content_prediction_model.pkl")

sample = [
    "I hate everyone in this group."
]

prediction = model.predict(sample)

print("Encoded Prediction:", prediction[0])

label_map = {0: "HOF", 1: "NOT"}   # Change if your encoding is different

print("Predicted Label:", label_map[prediction[0]])
# Out:
# Encoded Prediction: 1
# Predicted Label: NOT

# %%
# ==========================================
# Step 9: Predict Multiple Texts
# ==========================================

samples = [
    "I hate everyone in this group.",
    "You are an idiot.",
    "I will kill you.",
    "Thank you for your help.",
    "Have a nice day.",
    "Go to hell.",
    "You deserve respect.",
    "I love my family."
]

predictions = model.predict(samples)

label_map = {0: "HOF", 1: "NOT"}   # Change if your encoding is different

print("="*60)

for text, pred in zip(samples, predictions):
    print("Text :", text)
    print("Prediction :", label_map[pred])
    print("-"*60)
# Out:
# ============================================================
# Text : I hate everyone in this group.
# Prediction : NOT
# ------------------------------------------------------------
# Text : You are an idiot.
# Prediction : HOF
# ------------------------------------------------------------
# Text : I will kill you.
# Prediction : NOT
# ------------------------------------------------------------
# Text : Thank you for your help.
# Prediction : NOT
# ------------------------------------------------------------
# Text : Have a nice day.
# Prediction : NOT
# ------------------------------------------------------------
# Text : Go to hell.
# Prediction : NOT
# ------------------------------------------------------------
# Text : You deserve respect.
# Prediction : NOT
# ------------------------------------------------------------
# Text : I love my family.
# Prediction : NOT
# ------------------------------------------------------------

# %%
# ==========================================
# Step 10: Prediction Probability
# ==========================================

sample = [
    "I hate everyone in this group."
]

probability = model.predict_proba(sample)

print("Classes :", model.classes_)
print("Probability :", probability)
# Out:
# Classes : [0 1]
# Probability : [[0.39089795 0.60910205]]

# %%
# ==========================================
# Step 11: Classification Report
# ==========================================

from sklearn.metrics import classification_report

y_pred = pipeline.predict(X_test_text)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.36      0.46       452
#            1       0.68      0.87      0.76       719
#
#     accuracy                           0.67      1171
#    macro avg       0.66      0.61      0.61      1171
# weighted avg       0.66      0.67      0.65      1171

# %%
# ==========================================
# Step 12: Confusion Matrix
# ==========================================

from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

print("Confusion Matrix")
print(cm)
# Out:
# Confusion Matrix
# [[161 291]
#  [ 94 625]]

# %%
# ==========================================
# Step 13: Confusion Matrix Heatmap
# ==========================================

import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm
)

disp.plot(cmap="Blues")

plt.title("Confusion Matrix")

plt.show()

# %%
# ==========================================
# Step 14: Accuracy
# ==========================================

from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)

print("Accuracy :", accuracy)
# Out:
# Accuracy : 0.6712211784799317

# %%
# ==========================================
# Step 15: Save Predictions
# ==========================================

import pandas as pd

prediction_df = pd.DataFrame({
    "Text": X_test_text,
    "Actual": y_test,
    "Predicted": y_pred
})

prediction_df.to_csv(
    "Harmful_Content_Model_Predictions.csv",
    index=False
)

print("Predictions saved successfully.")
# Out:
# Predictions saved successfully.

# %%
# ==========================================
# Step 16: Cross Validation
# ==========================================

from sklearn.model_selection import cross_val_score

scores = cross_val_score(
    pipeline,
    X_text,
    y,
    cv=5,
    scoring="accuracy"
)

print("Cross Validation Scores:")
print(scores)

print("Average Accuracy:", scores.mean())
# Out:
# Cross Validation Scores:
# [0.71391973 0.69086251 0.61538462 0.65641026 0.60940171]
# Average Accuracy: 0.6571957637201018

# %%
from sklearn.metrics import RocCurveDisplay

RocCurveDisplay.from_estimator(
    pipeline,
    X_test_text,
    y_test
)

plt.show()

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

print("Precision :", precision_score(y_test, y_pred))
print("Recall    :", recall_score(y_test, y_pred))
print("F1 Score  :", f1_score(y_test, y_pred))
# Out:
# Precision : 0.6823144104803494
# Recall    : 0.8692628650904033
# F1 Score  : 0.764525993883792

# %%
feature_names = pipeline.named_steps["tfidf"].get_feature_names_out()

coef = pipeline.named_steps["classifier"].coef_[0]

top_positive = coef.argsort()[-20:]
top_negative = coef.argsort()[:20]

print("Top Harmful Words")
print(feature_names[top_positive])

print("\nTop Non-Harmful Words")
print(feature_names[top_negative])
# Out:
# Top Harmful Words
# ['controversy' 'war' 'wonderful' 'imagine' 'wait' 'justice' 'happy'
#  'happy johnmccainday' 'real' 'conservative' 'gstephanopoulos'
#  'doctorstrike' 'borisjohnsonshouldnotbepm' 'wasnt' 'doctors' 'new'
#  'dhoni' 'shameonicc' 'doctorsfightback' 'dhonikeepstheglove']
#
# Top Non-Harmful Words
# ['fuck' 'fucking' 'youre' 'shit' 'ass' 'traitor' 'sick' 'stupid'
#  'president' 'hes' 'idiot' 'liar' 'bitch' 'trumpisadisgrace' 'moron'
#  'council' 'borisjohnson' 'racist' 'dickhead' 'planning']

# %%
while True:
    text = input("Enter text (type exit to stop): ")

    if text.lower() == "exit":
        break

    prediction = pipeline.predict([text])

    print("Prediction:", prediction[0])
# Out:
# Enter text (type exit to stop):  89
# Prediction: 1
# Enter text (type exit to stop):  34
# Prediction: 1
# Enter text (type exit to stop):  43
# Prediction: 1
# Enter text (type exit to stop):  43
# Prediction: 1
# Enter text (type exit to stop):  6
# Prediction: 1
# Enter text (type exit to stop):  65
# Prediction: 1
# Enter text (type exit to stop):  exit

# %%
import pandas as pd
import numpy as np

from sqlalchemy import create_engine
from sqlalchemy.engine import URL

# %%
print(df.columns.tolist())
# Out:
# ['text_id', 'text', 'task_1', 'task_2', 'task_3', 'text_length', 'task_1_encoded']

# %%
connection_url = URL.create(
    drivername="mysql+pymysql",
    username="root",
    password="MyNewPassword",
    host="localhost",
    port=3306,
    database="government_social_media"
)

engine = create_engine(connection_url)

print("✅ Connected Successfully")
# Out:
# ✅ Connected Successfully

# %%
harmful_df = pd.read_sql(
    "SELECT * FROM harmful_content",
    engine
)

# %%
print(harmful_df.shape)
# Out:
# (5852, 5)

# %%
harmful_df.head()
# Out:
#       text_id                                               text task_1  \
# 0  hasoc_en_1  #DhoniKeepsTheGlove | WATCH: Sports Minister K...    NOT
# 1  hasoc_en_2  @politico No. We should remember very clearly ...    HOF
# 2  hasoc_en_3  @cricketworldcup Guess who would be the winner...    NOT
# 3  hasoc_en_4  Corbyn is too politically intellectual for #Bo...    NOT
# 4  hasoc_en_5  All the best to #TeamIndia for another swimmin...    NOT
#
#   task_2 task_3
# 0   NONE   NONE
# 1   HATE    TIN
# 2   NONE   NONE
# 3   NONE   NONE
# 4   NONE   NONE

# %%
print(harmful_df.columns)
# Out:
# Index(['text_id', 'text', 'task_1', 'task_2', 'task_3'], dtype='object')

# %%
harmful_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5852 entries, 0 to 5851
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   text_id  5852 non-null   object
#  1   text     5852 non-null   object
#  2   task_1   5852 non-null   object
#  3   task_2   5852 non-null   object
#  4   task_3   5852 non-null   object
# dtypes: object(5)
# memory usage: 228.7+ KB

# %%
harmful_df.isnull().sum()
# Out:
# text_id    0
# text       0
# task_1     0
# task_2     0
# task_3     0
# dtype: int64

# %%
harmful_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
harmful_df.describe(include="all")
# Out:
#            text_id                                               text task_1  \
# count         5852                                               5852   5852
# unique        5852                                               5828      2
# top     hasoc_en_1  By wearing the #BalidaanBadge over his gloves ...    NOT
# freq             1                                                  5   3591
#
#        task_2 task_3
# count    5852   5852
# unique      4      3
# top      NONE   NONE
# freq     3591   3591

# %% [markdown]
# #### Step2: Harmful Content Detection
# The first preprocessing step is to identify missing values in the dataset. Missing values can reduce model performance, so they are detected and removed before further analysis.

# %%
# Check missing values
harmful_df.isnull().sum()
# Out:
# text_id    0
# text       0
# task_1     0
# task_2     0
# task_3     0
# dtype: int64

# %%
# Remove missing values
harmful_df = harmful_df.dropna()

# Verify
harmful_df.isnull().sum()
# Out:
# text_id    0
# text       0
# task_1     0
# task_2     0
# task_3     0
# dtype: int64

# %%
# Check duplicate records
harmful_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Remove duplicate records
harmful_df = harmful_df.drop_duplicates()

# Verify
harmful_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
harmful_df["text"] = harmful_df["text"].str.lower()

harmful_df.head()
# Out:
#       text_id                                               text task_1  \
# 0  hasoc_en_1  #dhonikeepstheglove | watch: sports minister k...    NOT
# 1  hasoc_en_2  @politico no. we should remember very clearly ...    HOF
# 2  hasoc_en_3  @cricketworldcup guess who would be the winner...    NOT
# 3  hasoc_en_4  corbyn is too politically intellectual for #bo...    NOT
# 4  hasoc_en_5  all the best to #teamindia for another swimmin...    NOT
#
#   task_2 task_3
# 0   NONE   NONE
# 1   HATE    TIN
# 2   NONE   NONE
# 3   NONE   NONE
# 4   NONE   NONE

# %%
harmful_df["text"] = harmful_df["text"].str.strip()

harmful_df.head()
# Out:
#       text_id                                               text task_1  \
# 0  hasoc_en_1  #dhonikeepstheglove | watch: sports minister k...    NOT
# 1  hasoc_en_2  @politico no. we should remember very clearly ...    HOF
# 2  hasoc_en_3  @cricketworldcup guess who would be the winner...    NOT
# 3  hasoc_en_4  corbyn is too politically intellectual for #bo...    NOT
# 4  hasoc_en_5  all the best to #teamindia for another swimmin...    NOT
#
#   task_2 task_3
# 0   NONE   NONE
# 1   HATE    TIN
# 2   NONE   NONE
# 3   NONE   NONE
# 4   NONE   NONE

# %%
import string

harmful_df["text"] = harmful_df["text"].str.replace(
    f"[{string.punctuation}]",
    "",
    regex=True
)

harmful_df.head()
# Out:
#       text_id                                               text task_1  \
# 0  hasoc_en_1  dhonikeepstheglove  watch sports minister kire...    NOT
# 1  hasoc_en_2  politico no we should remember very clearly th...    HOF
# 2  hasoc_en_3  cricketworldcup guess who would be the winner ...    NOT
# 3  hasoc_en_4  corbyn is too politically intellectual for bor...    NOT
# 4  hasoc_en_5  all the best to teamindia for another swimming...    NOT
#
#   task_2 task_3
# 0   NONE   NONE
# 1   HATE    TIN
# 2   NONE   NONE
# 3   NONE   NONE
# 4   NONE   NONE

# %%
harmful_df["text"] = harmful_df["text"].str.replace(
    r"\d+",
    "",
    regex=True
)

harmful_df.head()
# Out:
#       text_id                                               text task_1  \
# 0  hasoc_en_1  dhonikeepstheglove  watch sports minister kire...    NOT
# 1  hasoc_en_2  politico no we should remember very clearly th...    HOF
# 2  hasoc_en_3  cricketworldcup guess who would be the winner ...    NOT
# 3  hasoc_en_4  corbyn is too politically intellectual for bor...    NOT
# 4  hasoc_en_5  all the best to teamindia for another swimming...    NOT
#
#   task_2 task_3
# 0   NONE   NONE
# 1   HATE    TIN
# 2   NONE   NONE
# 3   NONE   NONE
# 4   NONE   NONE

# %%
harmful_df["text"] = harmful_df["text"].str.replace(
    r"[^a-zA-Z\s]",
    "",
    regex=True
)

harmful_df.head()
# Out:
#       text_id                                               text task_1  \
# 0  hasoc_en_1  dhonikeepstheglove  watch sports minister kire...    NOT
# 1  hasoc_en_2  politico no we should remember very clearly th...    HOF
# 2  hasoc_en_3  cricketworldcup guess who would be the winner ...    NOT
# 3  hasoc_en_4  corbyn is too politically intellectual for bor...    NOT
# 4  hasoc_en_5  all the best to teamindia for another swimming...    NOT
#
#   task_2 task_3
# 0   NONE   NONE
# 1   HATE    TIN
# 2   NONE   NONE
# 3   NONE   NONE
# 4   NONE   NONE

# %%
print("Dataset Shape :", harmful_df.shape)

harmful_df.head()
# Out:
# Dataset Shape : (5852, 5)
#       text_id                                               text task_1  \
# 0  hasoc_en_1  dhonikeepstheglove  watch sports minister kire...    NOT
# 1  hasoc_en_2  politico no we should remember very clearly th...    HOF
# 2  hasoc_en_3  cricketworldcup guess who would be the winner ...    NOT
# 3  hasoc_en_4  corbyn is too politically intellectual for bor...    NOT
# 4  hasoc_en_5  all the best to teamindia for another swimming...    NOT
#
#   task_2 task_3
# 0   NONE   NONE
# 1   HATE    TIN
# 2   NONE   NONE
# 3   NONE   NONE
# 4   NONE   NONE

# %%
harmful_df.to_sql(
    "harmful_content_cleaned",
    con=engine,
    if_exists="replace",
    index=False
)

print("✅ Cleaned dataset saved successfully.")
# Out:
# ✅ Cleaned dataset saved successfully.

# %% [markdown]
# #### Step 3:Feature Engineering

# %% [markdown]
# ##### The objective of this module is to transform the cleaned text data into numerical features that can be understood by machine learning algorithms. Feature engineering improves the quality of input data and enables the model to learn meaningful patterns for harmful content classification.

# %%
# Display all column names
print(harmful_df.columns)
# Out:
# Index(['text_id', 'text', 'task_1', 'task_2', 'task_3'], dtype='object')

# %%
harmful_df.columns
# Out:
# Index(['text_id', 'text', 'task_1', 'task_2', 'task_3'], dtype='object')

# %%
harmful_df.columns.tolist()
# Out:
# ['text_id', 'text', 'task_1', 'task_2', 'task_3']

# %%
harmful_df.head()
# Out:
#       text_id                                               text task_1  \
# 0  hasoc_en_1  dhonikeepstheglove  watch sports minister kire...    NOT
# 1  hasoc_en_2  politico no we should remember very clearly th...    HOF
# 2  hasoc_en_3  cricketworldcup guess who would be the winner ...    NOT
# 3  hasoc_en_4  corbyn is too politically intellectual for bor...    NOT
# 4  hasoc_en_5  all the best to teamindia for another swimming...    NOT
#
#   task_2 task_3
# 0   NONE   NONE
# 1   HATE    TIN
# 2   NONE   NONE
# 3   NONE   NONE
# 4   NONE   NONE

# %%
X = harmful_df["text"]
y = harmful_df["task_1"]

print("Input Shape :", X.shape)
print("Target Shape:", y.shape)
# Out:
# Input Shape : (5852,)
# Target Shape: (5852,)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

y = label_encoder.fit_transform(y)

print("Classes :", label_encoder.classes_)
# Out:
# Classes : ['HOF' 'NOT']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(
    max_features=5000,
    stop_words="english"
)

# %%
X = tfidf.fit_transform(X)

print(X.shape)
# Out:
# (5852, 5000)

# %%
print(type(X))
# Out:
# <class 'scipy.sparse._csr.csr_matrix'>

# %%
print(tfidf.get_feature_names_out()[:20])
# Out:
# ['aajtak' 'ab' 'abandoned' 'abc' 'ability' 'able' 'abortion' 'abortions'
#  'abpanandatv' 'abpnewstv' 'abrandnewdayoutnow' 'absolute' 'absolutely'
#  'abt' 'abu' 'abuse' 'abuser' 'abuses' 'abusing' 'abusive']

# %%
print("="*60)
print("Module 3 Completed Successfully")
print("="*60)

print("Number of Features :", X.shape[1])
print("Number of Samples  :", X.shape[0])
# Out:
# ============================================================
# Module 3 Completed Successfully
# ============================================================
# Number of Features : 5000
# Number of Samples  : 5852

# %% [markdown]
# #### Step 4:Harmful Content Model Preparation
# The objective of this module is to split the feature matrix and target variable into training and testing datasets. This ensures that the machine learning models are trained on one portion of the data and evaluated on unseen data for reliable performance assessment.

# %% [markdown]
# ##### Step 1: Selection of Input and Target Variables
#
# The harmful content dataset is divided into input features (X) and the target variable (Y). The text column is selected as the input feature, while the harmful content label/category (task_1) is selected as the target variable for classification.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %% [markdown]
# ##### Step 2: Text Feature Engineering using TF-IDF
#
# Machine learning algorithms require numerical input. Therefore, the harmful content text is converted into numerical vectors using the TF-IDF Vectorizer.
#
# TF-IDF assigns higher importance to informative words while reducing the importance of commonly occurring words.

# %%
print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)
# Out:
# X_train: (4681, 5000)
# X_test : (1171, 5000)
# y_train: (4681,)
# y_test : (1171,)

# %% [markdown]
# ### step 5:Train-Test Split
# Splitting the dataset into training and testing sets helps evaluate the model's ability to generalize to new harmful content. It minimizes overfitting and provides an unbiased measure of classification performance.

# %% [markdown]
# ##### Step 1: Training and Testing Dataset Split
#
# The feature matrix and target variable are divided into training and testing datasets using the train_test_split() function. An 80:20 split is applied, and stratified sampling is used to preserve the class distribution in both datasets.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %% [markdown]
# ##### Step 2: Verification of Training and Testing Data
#
# The dimensions of the training and testing datasets are verified to confirm that the data has been successfully split for model development.

# %%
print("X_train Shape:", X_train.shape)
print("X_test Shape :", X_test.shape)
print("y_train Shape:", y_train.shape)
print("y_test Shape :", y_test.shape)
# Out:
# X_train Shape: (4681, 5000)
# X_test Shape : (1171, 5000)
# y_train Shape: (4681,)
# y_test Shape : (1171,)

# %% [markdown]
# #### step 6:Model Building
# Model building enables different machine learning algorithms to learn patterns from the harmful content dataset. Comparing multiple models helps identify the algorithm that provides the best classification performance.

# %%
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression(random_state=42)

lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
from sklearn.naive_bayes import MultinomialNB

nb_model = MultinomialNB()

nb_model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier(random_state=42)

dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
from sklearn.svm import LinearSVC

svm_model = LinearSVC(random_state=42)

svm_model.fit(X_train, y_train)
# Out:
# LinearSVC(random_state=42)

# %% [markdown]
# ### Model Building Summary
# Multiple machine learning classification models have been successfully trained using the harmful content dataset. These trained models are now ready for performance evaluation and comparison to identify the best-performing classifier.

# %% [markdown]
# #### step 7:Model Evaluation
# This module evaluates multiple classification models using standard evaluation metrics such as Accuracy, Precision, Recall, F1-Score, Confusion Matrix, and Classification Report. The results are used to compare model performance and select the most suitable model for harmful content detection.

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

lr_pred = lr_model.predict(X_test)

print("Accuracy :", accuracy_score(y_test, lr_pred))

print("\nClassification Report\n")
print(classification_report(y_test, lr_pred))

print("\nConfusion Matrix\n")
print(confusion_matrix(y_test, lr_pred))
# Out:
# Accuracy : 0.6669513236549958
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.63      0.33      0.43       452
#            1       0.68      0.88      0.76       719
#
#     accuracy                           0.67      1171
#    macro avg       0.65      0.60      0.60      1171
# weighted avg       0.66      0.67      0.64      1171
#
#
# Confusion Matrix
#
# [[148 304]
#  [ 86 633]]

# %%
nb_pred = nb_model.predict(X_test)

print("Accuracy :", accuracy_score(y_test, nb_pred))

print(classification_report(y_test, nb_pred))

print(confusion_matrix(y_test, nb_pred))
# Out:
# Accuracy : 0.6532877882152007
#               precision    recall  f1-score   support
#
#            0       0.58      0.35      0.44       452
#            1       0.67      0.84      0.75       719
#
#     accuracy                           0.65      1171
#    macro avg       0.63      0.60      0.59      1171
# weighted avg       0.64      0.65      0.63      1171
#
# [[160 292]
#  [114 605]]

# %%
dt_pred = dt_model.predict(X_test)

print("Accuracy :", accuracy_score(y_test, dt_pred))

print(classification_report(y_test, dt_pred))

print(confusion_matrix(y_test, dt_pred))
# Out:
# Accuracy : 0.591801878736123
#               precision    recall  f1-score   support
#
#            0       0.47      0.42      0.44       452
#            1       0.66      0.70      0.68       719
#
#     accuracy                           0.59      1171
#    macro avg       0.56      0.56      0.56      1171
# weighted avg       0.58      0.59      0.59      1171
#
# [[190 262]
#  [216 503]]

# %%
rf_pred = rf_model.predict(X_test)

print("Accuracy :", accuracy_score(y_test, rf_pred))

print(classification_report(y_test, rf_pred))

print(confusion_matrix(y_test, rf_pred))
# Out:
# Accuracy : 0.645602049530316
#               precision    recall  f1-score   support
#
#            0       0.58      0.31      0.40       452
#            1       0.66      0.86      0.75       719
#
#     accuracy                           0.65      1171
#    macro avg       0.62      0.58      0.57      1171
# weighted avg       0.63      0.65      0.61      1171
#
# [[139 313]
#  [102 617]]

# %%
svm_pred = svm_model.predict(X_test)

print("Accuracy :", accuracy_score(y_test, svm_pred))

print(classification_report(y_test, svm_pred))

print(confusion_matrix(y_test, svm_pred))
# Out:
# Accuracy : 0.623398804440649
#               precision    recall  f1-score   support
#
#            0       0.51      0.44      0.48       452
#            1       0.68      0.74      0.71       719
#
#     accuracy                           0.62      1171
#    macro avg       0.60      0.59      0.59      1171
# weighted avg       0.61      0.62      0.62      1171
#
# [[201 251]
#  [190 529]]

# %% [markdown]
# ### Model Evaluation Summary
#
# All trained machine learning models have been evaluated using standard classification metrics. Their performance results will be compared in the next module to identify the best-performing classifier for harmful content detection.

# %% [markdown]
# #### step 8:Model Comparison
# Different machine learning algorithms perform differently on the same dataset. Model comparison helps identify the classifier that provides the highest prediction accuracy and overall performance for harmful content detection.

# %%
from sklearn.metrics import accuracy_score

accuracy = {
    "Logistic Regression": accuracy_score(y_test, lr_pred),
    "Naive Bayes": accuracy_score(y_test, nb_pred),
    "Decision Tree": accuracy_score(y_test, dt_pred),
    "Random Forest": accuracy_score(y_test, rf_pred),
    "Support Vector Machine": accuracy_score(y_test, svm_pred)
}

accuracy
# Out:
# {'Logistic Regression': 0.6669513236549958,
#  'Naive Bayes': 0.6532877882152007,
#  'Decision Tree': 0.591801878736123,
#  'Random Forest': 0.645602049530316,
#  'Support Vector Machine': 0.623398804440649}

# %%
import pandas as pd

comparison = pd.DataFrame({
    "Model": accuracy.keys(),
    "Accuracy": accuracy.values()
})

comparison
# Out:
#                     Model  Accuracy
# 0     Logistic Regression  0.666951
# 1             Naive Bayes  0.653288
# 2           Decision Tree  0.591802
# 3           Random Forest  0.645602
# 4  Support Vector Machine  0.623399

# %%
comparison = comparison.sort_values(
    by="Accuracy",
    ascending=False
)

comparison
# Out:
#                     Model  Accuracy
# 0     Logistic Regression  0.666951
# 1             Naive Bayes  0.653288
# 3           Random Forest  0.645602
# 4  Support Vector Machine  0.623399
# 2           Decision Tree  0.591802

# %%
best_model = comparison.iloc[0]

print(best_model)
# Out:
# Model       Logistic Regression
# Accuracy               0.666951
# Name: 0, dtype: object

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.bar(comparison["Model"], comparison["Accuracy"])

plt.title("Model Accuracy Comparison")

plt.xlabel("Models")

plt.ylabel("Accuracy")

plt.xticks(rotation=20)

plt.show()

# %% [markdown]
# ### Model Comparison Summary
#
# The performance of all trained machine learning models has been successfully compared. The classifier with the highest accuracy is selected as the final model for harmful content detection.

# %% [markdown]
# #### step 9:Model Saving and Prediction
# Saving the trained model eliminates the need to retrain it every time new data is received. It enables efficient deployment and real-time harmful content prediction.

# %%
import joblib

joblib.dump(svm_model, "harmful_content_model.pkl")

print("Model Saved Successfully")
# Out:
# Model Saved Successfully

# %%
joblib.dump(tfidf, "tfidf_vectorizer.pkl")

print("Vectorizer Saved Successfully")
# Out:
# Vectorizer Saved Successfully

# %%
model = joblib.load("harmful_content_model.pkl")

vectorizer = joblib.load("tfidf_vectorizer.pkl")

# %%
sample_text = [
    "I hate everyone in this group."
]

sample_vector = vectorizer.transform(sample_text)

prediction = model.predict(sample_vector)

print(prediction)
# Out:
# [1]

# %%
print(label_encoder.classes_)
# Out:
# ['HOF' 'NOT']

# %%
comments = [
    "Thank you for your help.",
    "You are an idiot.",
    "The government service is excellent.",
    "I will destroy everything."
]

vectors = vectorizer.transform(comments)

predictions = model.predict(vectors)

# Convert numeric labels back to original labels
predicted_labels = label_encoder.inverse_transform(predictions)

for text, label in zip(comments, predicted_labels):
    print(f"{text} --> {label}")
# Out:
# Thank you for your help. --> HOF
# You are an idiot. --> HOF
# The government service is excellent. --> NOT
# I will destroy everything. --> NOT

# %%
predicted_labels = label_encoder.inverse_transform(predictions)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

y = label_encoder.fit_transform(y)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

y = label_encoder.fit_transform(y)

# %%
predictions = model.predict(vectors)

predicted_labels = label_encoder.inverse_transform(predictions)

for text, label in zip(comments, predicted_labels):
    print(f"{text} --> {label}")
# Out:
# Thank you for your help. --> 0
# You are an idiot. --> 0
# The government service is excellent. --> 1
# I will destroy everything. --> 1

# %%
print(predictions)
# Out:
# [0 0 1 1]

# %%
for text, label in zip(comments, predictions):
    print(f"{text} --> {label}")
# Out:
# Thank you for your help. --> 0
# You are an idiot. --> 0
# The government service is excellent. --> 1
# I will destroy everything. --> 1

# %%
print(predictions)
# Out:
# [0 0 1 1]

# %%
print("Best Model :", comparison.iloc[0]["Model"])
print("Accuracy   :", comparison.iloc[0]["Accuracy"])
# Out:
# Best Model : Logistic Regression
# Accuracy   : 0.6669513236549958

# %%
sample = ["This message contains abusive language."]

sample_vector = vectorizer.transform(sample)

prediction = model.predict(sample_vector)

print("Prediction :", prediction)
# Out:
# Prediction : [1]

# %%
prediction_label = label_encoder.inverse_transform(prediction)

print("Predicted Label :", prediction_label[0])
# Out:
# Predicted Label : 1

# %% [markdown]
# ### Project Summary
#
# The harmful content classification system was successfully developed using Natural Language Processing and machine learning techniques. The dataset was preprocessed, transformed into TF-IDF feature vectors, and used to train multiple classification models. After evaluating all models, the best-performing classifier was selected and saved for future prediction. The developed system can automatically classify harmful content and can be extended for real-world social media content moderation.

# %% [markdown]
# #### Future Enhancements
#
# The current system can be further improved by:
#
# Using deep learning models such as LSTM, BERT, or RoBERTa.
# Training on larger multilingual datasets.
# Developing a real-time web application using Flask or Streamlit.
# Deploying the model as a REST API for social media monitoring.
# Continuously updating the model with newly collected harmful content data.

# %% [markdown]
# #### step 10: Final Project Conclusion and Future Scope
# The project conclusion highlights the achievements of the developed classification system, while the future scope identifies opportunities for further research, optimization, and deployment.

# %% [markdown]
# ##### Step 1: Final Model Selection
#
# The best-performing machine learning model was selected based on its evaluation metrics, including Accuracy, Precision, Recall, and F1-Score. This model demonstrated the highest classification performance for harmful content detection.

# %%
print("Final Selected Model:", comparison.iloc[0]["Model"])
print("Accuracy:", comparison.iloc[0]["Accuracy"])
# Out:
# Final Selected Model: Logistic Regression
# Accuracy: 0.6669513236549958

# %% [markdown]
# ### Overall Project Summary
#
# The Harmful Content Detection system was successfully developed using Natural Language Processing (NLP) and machine learning techniques. The dataset was loaded from the MySQL database, preprocessed, transformed into TF-IDF feature vectors, and used to train multiple classification models. The trained models were evaluated, compared, and the best-performing model was selected for harmful content prediction.

# %% [markdown]
# #### pre reqisites

# %%
harmful_df.head()
# Out:
#       text_id                                               text task_1  \
# 0  hasoc_en_1  dhonikeepstheglove  watch sports minister kire...    NOT
# 1  hasoc_en_2  politico no we should remember very clearly th...    HOF
# 2  hasoc_en_3  cricketworldcup guess who would be the winner ...    NOT
# 3  hasoc_en_4  corbyn is too politically intellectual for bor...    NOT
# 4  hasoc_en_5  all the best to teamindia for another swimming...    NOT
#
#   task_2 task_3
# 0   NONE   NONE
# 1   HATE    TIN
# 2   NONE   NONE
# 3   NONE   NONE
# 4   NONE   NONE

# %%
print("Dataset Shape:", harmful_df.shape)
# Out:
# Dataset Shape: (5852, 5)

# %%
print(harmful_df.columns)
# Out:
# Index(['text_id', 'text', 'task_1', 'task_2', 'task_3'], dtype='object')

# %%
harmful_df.columns.tolist()
# Out:
# ['text_id', 'text', 'task_1', 'task_2', 'task_3']

# %%
X = harmful_df["text"]
y = harmful_df["task_1"]

# %%
print("Input Shape :", X.shape)
print("Target Shape:", y.shape)

print("\nSample Input:")
print(X.head())

print("\nSample Target:")
print(y.head())
# Out:
# Input Shape : (5852,)
# Target Shape: (5852,)
#
# Sample Input:
# 0    dhonikeepstheglove  watch sports minister kire...
# 1    politico no we should remember very clearly th...
# 2    cricketworldcup guess who would be the winner ...
# 3    corbyn is too politically intellectual for bor...
# 4    all the best to teamindia for another swimming...
# Name: text, dtype: object
#
# Sample Target:
# 0    NOT
# 1    HOF
# 2    NOT
# 3    NOT
# 4    NOT
# Name: task_1, dtype: object

# %%
# Define input feature (X)
X = harmful_df["text"]

# Define target variable (Y)
y = harmful_df["task_1"]

# %%
# Display the first five input records
print("Input Feature (X):")
print(X.head())

print("\n" + "="*60 + "\n")

# Display the first five target records
print("Target Variable (Y):")
print(y.head())
# Out:
# Input Feature (X):
# 0    dhonikeepstheglove  watch sports minister kire...
# 1    politico no we should remember very clearly th...
# 2    cricketworldcup guess who would be the winner ...
# 3    corbyn is too politically intellectual for bor...
# 4    all the best to teamindia for another swimming...
# Name: text, dtype: object
#
# ============================================================
#
# Target Variable (Y):
# 0    NOT
# 1    HOF
# 2    NOT
# 3    NOT
# 4    NOT
# Name: task_1, dtype: object

# %%
print("Input Shape (X):", X.shape)
print("Target Shape (Y):", y.shape)
# Out:
# Input Shape (X): (5852,)
# Target Shape (Y): (5852,)

# %%
# Count missing values in each column
print(harmful_df.isnull().sum())
# Out:
# text_id    0
# text       0
# task_1     0
# task_2     0
# task_3     0
# dtype: int64

# %%
harmful_df.isnull().sum()
# Out:
# text_id    0
# text       0
# task_1     0
# task_2     0
# task_3     0
# dtype: int64

# %%
df = harmful_df

# %%
print(df.isnull().sum())
# Out:
# text_id    0
# text       0
# task_1     0
# task_2     0
# task_3     0
# dtype: int64

# %%
harmful_df.info()
harmful_df.describe()
harmful_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5852 entries, 0 to 5851
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   text_id  5852 non-null   object
#  1   text     5852 non-null   object
#  2   task_1   5852 non-null   object
#  3   task_2   5852 non-null   object
#  4   task_3   5852 non-null   object
# dtypes: object(5)
# memory usage: 228.7+ KB
#       text_id                                               text task_1  \
# 0  hasoc_en_1  dhonikeepstheglove  watch sports minister kire...    NOT
# 1  hasoc_en_2  politico no we should remember very clearly th...    HOF
# 2  hasoc_en_3  cricketworldcup guess who would be the winner ...    NOT
# 3  hasoc_en_4  corbyn is too politically intellectual for bor...    NOT
# 4  hasoc_en_5  all the best to teamindia for another swimming...    NOT
#
#   task_2 task_3
# 0   NONE   NONE
# 1   HATE    TIN
# 2   NONE   NONE
# 3   NONE   NONE
# 4   NONE   NONE

# %%
df = harmful_df

# %%
df.info()
df.describe()
df.head()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5852 entries, 0 to 5851
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   text_id  5852 non-null   object
#  1   text     5852 non-null   object
#  2   task_1   5852 non-null   object
#  3   task_2   5852 non-null   object
#  4   task_3   5852 non-null   object
# dtypes: object(5)
# memory usage: 228.7+ KB
# text_id    0
# text       0
# task_1     0
# task_2     0
# task_3     0
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# text_id    0
# text       0
# task_1     0
# task_2     0
# task_3     0
# dtype: int64

# %% [markdown]
# #### no missing values are present

# %% [markdown]
# #### encoding

# %%
print(df.isnull().sum())
# Out:
# text_id    0
# text       0
# task_1     0
# task_2     0
# task_3     0
# dtype: int64

# %%
df = harmful_df.copy()

# %% [markdown]
# ##### Encoding

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer

# Feature
X = df["text"]

# Target
y = df["task_1"]

# Encode Target
label_encoder = LabelEncoder()

y = label_encoder.fit_transform(y)

# TF-IDF
tfidf = TfidfVectorizer(
    max_features=10000,
    stop_words="english",
    ngram_range=(1,2),
    min_df=2
)

X = tfidf.fit_transform(X)

print("Encoded Data Shape :", X.shape)
# Out:
# Encoded Data Shape : (5852, 10000)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training Samples :", len(y_train))
print("Testing Samples :", len(y_test))
# Out:
# Training Samples : 4681
# Testing Samples : 1171

# %%
#### Split the Data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training Samples :", len(y_train))
print("Testing Samples :", len(y_test))
# Out:
# Training Samples : 4681
# Testing Samples : 1171

# %%
### Model Building
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

model.fit(X_train, y_train)

print("Model Trained Successfully")
# Out:
# Model Trained Successfully

# %%
### Prediction
y_pred = model.predict(X_test)

# %%
### Accuracy
from sklearn.metrics import accuracy_score

train_accuracy = model.score(X_train, y_train)

test_accuracy = model.score(X_test, y_test)

print("Training Accuracy :", train_accuracy)

print("Testing Accuracy :", test_accuracy)
# Out:
# Training Accuracy : 0.9935911130100405
# Testing Accuracy : 0.6532877882152007

# %%
### Classification Report
from sklearn.metrics import classification_report

print(classification_report(
    y_test,
    y_pred,
    target_names=label_encoder.classes_
))
# Out:
#               precision    recall  f1-score   support
#
#          HOF       0.62      0.27      0.38       452
#          NOT       0.66      0.89      0.76       719
#
#     accuracy                           0.65      1171
#    macro avg       0.64      0.58      0.57      1171
# weighted avg       0.64      0.65      0.61      1171

# %%
#### Confusion Matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=label_encoder.classes_
)

disp.plot(cmap="Blues")

plt.title("Confusion Matrix")

plt.show()

# %%
#### Cross Validation
from sklearn.model_selection import cross_val_score

scores = cross_val_score(
    model,
    X,
    y,
    cv=5,
    scoring="accuracy"
)

print("Cross Validation Scores")

print(scores)

print("Mean Accuracy :", scores.mean())
# Out:
# Cross Validation Scores
# [0.72502135 0.69513237 0.62222222 0.65470085 0.5965812 ]
# Mean Accuracy : 0.6587315976555942

# %%
### Bias-Variance Analysis
print("Training Accuracy :", round(train_accuracy*100,2), "%")

print("Testing Accuracy :", round(test_accuracy*100,2), "%")

gap = abs(train_accuracy - test_accuracy)

print("Difference :", round(gap*100,2), "%")

if gap < 5:
    print("Model Status : Good Fit")
elif train_accuracy > test_accuracy:
    print("Model Status : Overfitting")
else:
    print("Model Status : Underfitting")
# Out:
# Training Accuracy : 99.36 %
# Testing Accuracy : 65.33 %
# Difference : 34.03 %
# Model Status : Good Fit

# %%
# ==========================================
# Step 1: Encoding
# ==========================================

from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer

# Feature (Input)
X = df["text"]

# Target (Output)
y = df["task_1"]

# Encode target labels
label_encoder = LabelEncoder()

y = label_encoder.fit_transform(y)

print("Label Mapping:")

for label, value in zip(
    label_encoder.classes_,
    label_encoder.transform(label_encoder.classes_)
):
    print(f"{label} --> {value}")

# Create TF-IDF Vectorizer
vectorizer = TfidfVectorizer(
    max_features=5000
)

# Transform text into numerical features
X = vectorizer.fit_transform(X)

print("\nEncoding Completed Successfully")

print("Feature Shape :", X.shape)
print("Target Shape  :", y.shape)
# Out:
# Label Mapping:
# HOF --> 0
# NOT --> 1
#
# Encoding Completed Successfully
# Feature Shape : (5852, 5000)
# Target Shape  : (5852,)

# %%
# ==========================================
# Step 2: Train-Test Split
# ==========================================

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training Samples :", X_train.shape[0])
print("Testing Samples  :", X_test.shape[0])
# Out:
# Training Samples : 4681
# Testing Samples  : 1171

# %%
# ==========================================
# Step 2: Train-Test Split
# ==========================================

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training Samples :", X_train.shape[0])
print("Testing Samples  :", X_test.shape[0])
# Out:
# Training Samples : 4681
# Testing Samples  : 1171

# %%
# ==========================================
# Step 3: Import Machine Learning Models
# ==========================================

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
# ==========================================
# Step 4: Create Machine Learning Models
# ==========================================

models = {

    "Logistic Regression": LogisticRegression(
        max_iter=3000,
        random_state=42
    ),

    "K-Nearest Neighbors": KNeighborsClassifier(
        n_neighbors=5
    ),

    "Naive Bayes": MultinomialNB(),

    "Support Vector Machine": LinearSVC(
        random_state=42
    ),

    "Decision Tree": DecisionTreeClassifier(
        random_state=42
    ),

    "Random Forest": RandomForestClassifier(
        n_estimators=100,
        random_state=42
    )

}

print("All Models Created Successfully")
# Out:
# All Models Created Successfully

# %%
# ==========================================
# Step 5: Train All Models
# ==========================================

trained_models = {}

for name, model in models.items():

    model.fit(X_train, y_train)

    trained_models[name] = model

    print(f"{name} trained successfully.")
# Out:
# Logistic Regression trained successfully.
# K-Nearest Neighbors trained successfully.
# Naive Bayes trained successfully.
# Support Vector Machine trained successfully.
# Decision Tree trained successfully.
# Random Forest trained successfully.

# %%
# ==========================================
# Step 6: Predict Test Data
# ==========================================

predictions = {}

for name, model in trained_models.items():

    predictions[name] = model.predict(X_test)

print("Predictions Completed Successfully")
# Out:
# Predictions Completed Successfully

# %%
# ==========================================
# Step 7: Evaluate All Models
# ==========================================

from sklearn.metrics import accuracy_score, f1_score
import pandas as pd

results = []

for name, model in trained_models.items():

    train_pred = model.predict(X_train)
    test_pred = model.predict(X_test)

    train_acc = accuracy_score(y_train, train_pred)
    test_acc = accuracy_score(y_test, test_pred)

    train_f1 = f1_score(
        y_train,
        train_pred,
        average="weighted"
    )

    test_f1 = f1_score(
        y_test,
        test_pred,
        average="weighted"
    )

    if train_acc > test_acc + 0.05:
        status = "Overfitting"
    elif train_acc < 0.80 and test_acc < 0.80:
        status = "Underfitting"
    else:
        status = "Good Fit"

    results.append({
        "Model": name,
        "Training Accuracy": round(train_acc,4),
        "Testing Accuracy": round(test_acc,4),
        "Training F1 Score": round(train_f1,4),
        "Testing F1 Score": round(test_f1,4),
        "Model Status": status
    })

comparison = pd.DataFrame(results)

comparison = comparison.sort_values(
    by="Testing Accuracy",
    ascending=False
).reset_index(drop=True)

comparison
# Out:
#                     Model  Training Accuracy  Testing Accuracy  \
# 0     Logistic Regression             0.8032            0.6695
# 1             Naive Bayes             0.7949            0.6567
# 2           Random Forest             0.9940            0.6550
# 3  Support Vector Machine             0.9378            0.6277
# 4     K-Nearest Neighbors             0.6191            0.6174
# 5           Decision Tree             0.9940            0.5892
#
#    Training F1 Score  Testing F1 Score  Model Status
# 0             0.7920            0.6366   Overfitting
# 1             0.7790            0.6208   Overfitting
# 2             0.9940            0.6123   Overfitting
# 3             0.9375            0.6186   Overfitting
# 4             0.4817            0.4779  Underfitting
# 5             0.9940            0.5847   Overfitting

# %%
# ==========================================
# Step 8: Best Model
# ==========================================

best_model_name = comparison.iloc[0]["Model"]

best_model = trained_models[best_model_name]

print("Best Model :", best_model_name)
# Out:
# Best Model : Logistic Regression

# %%
# ==========================================
# Step 9: Classification Report
# ==========================================

from sklearn.metrics import classification_report

# Prediction
y_pred = best_model.predict(X_test)

# Classification Report
print("Classification Report\n")

print(
    classification_report(
        y_test,
        y_pred,
        target_names=label_encoder.classes_
    )
)
# Out:
# Classification Report
#
#               precision    recall  f1-score   support
#
#          HOF       0.64      0.32      0.43       452
#          NOT       0.68      0.89      0.77       719
#
#     accuracy                           0.67      1171
#    macro avg       0.66      0.60      0.60      1171
# weighted avg       0.66      0.67      0.64      1171

# %%
# ==========================================
# Step 10: Confusion Matrix
# ==========================================

from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=label_encoder.classes_
)

fig, ax = plt.subplots(figsize=(8,6))

disp.plot(cmap="Blues", ax=ax)

plt.title("Confusion Matrix")

plt.show()

# %%
# ==========================================
# Step 11: Cross Validation
# ==========================================

from sklearn.model_selection import cross_val_score

scores = cross_val_score(
    best_model,
    X,
    y,
    cv=5,
    scoring="accuracy"
)

print("Cross Validation Scores")
print(scores)

print("\nMean Accuracy :", round(scores.mean(),4))
# Out:
# Cross Validation Scores
# [0.72416738 0.6823228  0.62991453 0.64529915 0.60854701]
#
# Mean Accuracy : 0.6581

# %%
# ==========================================
# Step 12: Save Best Model
# ==========================================

import joblib

joblib.dump(best_model, "harmful_content_model.pkl")

joblib.dump(vectorizer, "tfidf_vectorizer.pkl")

joblib.dump(label_encoder, "label_encoder.pkl")

print("Model Saved Successfully")
# Out:
# Model Saved Successfully

# %%
# ==========================================
# Step 13: Load Saved Model
# ==========================================

import joblib

model = joblib.load("harmful_content_model.pkl")

vectorizer = joblib.load("tfidf_vectorizer.pkl")

encoder = joblib.load("label_encoder.pkl")

print("Model Loaded Successfully")
# Out:
# Model Loaded Successfully

# %%
# ==========================================
# Step 14: Predict Single Text
# ==========================================

new_text = [
    "I hate everyone in this group."
]

new_vector = vectorizer.transform(new_text)

prediction = model.predict(new_vector)

prediction = encoder.inverse_transform(prediction)

print("Input Text :")
print(new_text[0])

print("\nPredicted Label :")
print(prediction[0])
# Out:
# Input Text :
# I hate everyone in this group.
#
# Predicted Label :
# NOT

# %%
# ==========================================
# Step 15: Predict Multiple Texts
# ==========================================

texts = [
    "Thank you for your support.",
    "You are an idiot.",
    "I hate everyone.",
    "The government service is excellent.",
    "I will destroy everything.",
    "Let's work together.",
    "Have a wonderful day.",
    "You are amazing."
]

vectors = vectorizer.transform(texts)

predictions = model.predict(vectors)

predicted_labels = encoder.inverse_transform(predictions)

import pandas as pd

prediction_df = pd.DataFrame({
    "Input Text": texts,
    "Predicted Label": predicted_labels
})

prediction_df
# Out:
#                              Input Text Predicted Label
# 0           Thank you for your support.             NOT
# 1                     You are an idiot.             HOF
# 2                      I hate everyone.             NOT
# 3  The government service is excellent.             NOT
# 4            I will destroy everything.             NOT
# 5                  Let's work together.             NOT
# 6                 Have a wonderful day.             NOT
# 7                      You are amazing.             NOT

# %% [markdown]
# # ==========================================
# # Step 16: Final Model Selection
# # ==========================================
#
# comparison

# %% [markdown]
# ### Final Model Evaluation

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

# Predictions
y_pred = best_model.predict(X_test)

print("Test Accuracy :",
      round(accuracy_score(y_test, y_pred),4))

print("Weighted Precision :",
      round(precision_score(y_test, y_pred,
      average="weighted"),4))

print("Weighted Recall :",
      round(recall_score(y_test, y_pred,
      average="weighted"),4))

print("Weighted F1 Score :",
      round(f1_score(y_test, y_pred,
      average="weighted"),4))
# Out:
# Test Accuracy : 0.6695
# Weighted Precision : 0.6635
# Weighted Recall : 0.6695
# Weighted F1 Score : 0.6366

# %%
### Classification Report
from sklearn.metrics import classification_report

print(classification_report(
    y_test,
    y_pred,
    target_names=label_encoder.classes_
))
# Out:
#               precision    recall  f1-score   support
#
#          HOF       0.64      0.32      0.43       452
#          NOT       0.68      0.89      0.77       719
#
#     accuracy                           0.67      1171
#    macro avg       0.66      0.60      0.60      1171
# weighted avg       0.66      0.67      0.64      1171

# %%
### Confusion Matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=label_encoder.classes_
)

fig, ax = plt.subplots(figsize=(8,6))

disp.plot(cmap="Blues", ax=ax)

plt.title("Confusion Matrix - Harmful Content Detection")

plt.show()

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# ==========================================
# Create Final Dataset
# ==========================================

# Make a copy of the processed dataset
final_dataset = df.copy()

# Clean text column
final_dataset["text"] = (
    final_dataset["text"]
    .fillna("")
    .astype(str)
    .str.strip()
)

# Clean target column
final_dataset["task_1"] = (
    final_dataset["task_1"]
    .fillna("")
    .astype(str)
    .str.strip()
)

# Remove empty rows
final_dataset = final_dataset[
    (final_dataset["text"] != "") &
    (final_dataset["task_1"] != "")
]

# Add Text Length feature
final_dataset["text_length"] = final_dataset["text"].apply(len)

# Encode Target Labels
label_encoder = LabelEncoder()

final_dataset["task_1_encoded"] = label_encoder.fit_transform(
    final_dataset["task_1"]
)

# Save Final Dataset
output_file = "Final_Harmful_Content_Dataset.csv"

final_dataset.to_csv(
    output_file,
    index=False,
    encoding="utf-8-sig"
)

print("Dataset exported successfully.")
print("File Name :", output_file)
print("Rows      :", final_dataset.shape[0])
print("Columns   :", final_dataset.shape[1])
# Out:
# Dataset exported successfully.
# File Name : Final_Harmful_Content_Dataset.csv
# Rows      : 5852
# Columns   : 7

# %%
import pandas as pd

# ==========================================
# Export TF-IDF Training Dataset
# ==========================================

# Convert sparse TF-IDF matrix into DataFrame
tfidf_df = pd.DataFrame(
    X_train.toarray(),
    columns=vectorizer.get_feature_names_out()
)

# Add encoded target column
tfidf_df["task_1_encoded"] = y_train

# Add original target labels
tfidf_df["task_1"] = label_encoder.inverse_transform(y_train)

# Save TF-IDF dataset
output_file = "TFIDF_Harmful_Content_Training_Dataset.csv"

tfidf_df.to_csv(
    output_file,
    index=False,
    encoding="utf-8-sig"
)

print("TF-IDF dataset exported successfully.")
print("File Name :", output_file)
print("Rows      :", tfidf_df.shape[0])
print("Columns   :", tfidf_df.shape[1])
# Out:
# TF-IDF dataset exported successfully.
# File Name : TFIDF_Harmful_Content_Training_Dataset.csv
# Rows      : 4681
# Columns   : 5002

# %%
import pandas as pd

# ==========================================
# Export Model Predictions
# ==========================================

# Predict on test dataset
final_predictions = best_model.predict(X_test)

# Create DataFrame
prediction_df = pd.DataFrame({
    "Actual": label_encoder.inverse_transform(y_test),
    "Predicted": label_encoder.inverse_transform(final_predictions)
})

# Save CSV
output_file = "Harmful_Content_Model_Predictions.csv"

prediction_df.to_csv(
    output_file,
    index=False,
    encoding="utf-8-sig"
)

print("Predictions exported successfully.")
print("File Name :", output_file)
print("Rows      :", prediction_df.shape[0])
print("Columns   :", prediction_df.shape[1])

# Display first 10 predictions
prediction_df.head(10)
# Out:
# Predictions exported successfully.
# File Name : Harmful_Content_Model_Predictions.csv
# Rows      : 1171
# Columns   : 2
#   Actual Predicted
# 0    NOT       NOT
# 1    NOT       NOT
# 2    NOT       NOT
# 3    NOT       NOT
# 4    NOT       NOT
# 5    NOT       NOT
# 6    HOF       NOT
# 7    NOT       NOT
# 8    HOF       HOF
# 9    NOT       NOT

# %%
output_file = "Final_Harmful_Content_Dataset.csv"

# %%
import os

print("Current Working Directory:")
print(os.getcwd())
# Out:
# Current Working Directory:
# C:\Users\kyatham chaitanya\government_social_media

# %%
import os

print(os.path.exists("Final_Harmful_Content_Dataset.csv"))
# Out:
# True

# %%
import os

print(os.path.expanduser("~"))
# Out:
# C:\Users\kyatham chaitanya

# %%
import os

print("Home Folder:")
print(os.path.expanduser("~"))

print("\nCurrent Folder:")
print(os.getcwd())
# Out:
# Home Folder:
# C:\Users\kyatham chaitanya
#
# Current Folder:
# C:\Users\kyatham chaitanya\government_social_media

# %%
import os

print(os.path.exists(r"C:\Users\kyatham chaitanya\Downloads"))
# Out:
# True

# %%
output_file = r"C:\Users\kyatham chaitanya\Downloads\Final_Harmful_Content_Dataset.csv"

final_dataset.to_csv(
    output_file,
    index=False,
    encoding="utf-8-sig"
)

print("Saved Successfully!")
print(output_file)
# Out:
# Saved Successfully!
# C:\Users\kyatham chaitanya\Downloads\Final_Harmful_Content_Dataset.csv

# %%
joblib.dump(best_model, "harmful_content_model.pkl")
# Out:
# ['harmful_content_model.pkl']

# %%
import joblib

model = joblib.load("harmful_content_model.pkl")

print(type(model))
print(model)
# Out:
# <class 'sklearn.linear_model._logistic.LogisticRegression'>
# LogisticRegression(max_iter=3000, random_state=42)

# %%
import joblib

model = joblib.load("harmful_content_model.pkl")
vectorizer = joblib.load("tfidf_vectorizer.pkl")
label_encoder = joblib.load("label_encoder.pkl")

print("Model Loaded Successfully!")
print(model)
# Out:
# Model Loaded Successfully!
# LogisticRegression(max_iter=3000, random_state=42)

# %%
import os

for file in os.listdir():
    if file.endswith(".pkl"):
        print(file)
# Out:
# best_harmful_content_model.pkl
# harmful_content_model.pkl
# harmful_content_prediction_model.pkl
# label_encoder.pkl
# tfidf_vectorizer.pkl

# %%
joblib.dump(best_model, "harmful_content_model.pkl")
# Out:
# ['harmful_content_model.pkl']

# %%
RandomForestClassifier(...)
# Out:
# RandomForestClassifier(n_estimators=Ellipsis)

# %%
print(type(model))
# Out:
# <class 'sklearn.linear_model._logistic.LogisticRegression'>

# %%
import joblib

joblib.dump(best_model,
            "harmful_content_model.pkl")

joblib.dump(vectorizer,
            "tfidf_vectorizer.pkl")

joblib.dump(label_encoder,
            "label_encoder.pkl")

print("Model Saved Successfully")
# Out:
# Model Saved Successfully

# %%
#### Load Saved Model
import joblib

loaded_model = joblib.load(
    "harmful_content_model.pkl"
)

loaded_vectorizer = joblib.load(
    "tfidf_vectorizer.pkl"
)

loaded_encoder = joblib.load(
    "label_encoder.pkl"
)

print("Model Loaded Successfully")
# Out:
# Model Loaded Successfully

# %%
import os

print([f for f in os.listdir() if f.endswith(".pkl")])
# Out:
# ['best_harmful_content_model.pkl', 'harmful_content_model.pkl', 'harmful_content_prediction_model.pkl', 'label_encoder.pkl', 'tfidf_vectorizer.pkl']

# %%
new_text = """
I hate everyone in this group.
"""

# Convert text into TF-IDF features
new_vector = loaded_vectorizer.transform([new_text])

# Predict class
prediction = loaded_model.predict(new_vector)

# Convert encoded label back to original label
predicted_label = loaded_encoder.inverse_transform(prediction)

print("Input Text:")
print(new_text)

print("\nPredicted Label:")
print(predicted_label[0])
# Out:
# Input Text:
#
# I hate everyone in this group.
#
#
# Predicted Label:
# NOT

# %%
tfidf = TfidfVectorizer(
    max_features=5000,
    stop_words="english",
    ngram_range=(1,2),
    min_df=2,
    max_df=0.95,
    sublinear_tf=True
)

# %%
print(type(model))
# Out:
# <class 'sklearn.linear_model._logistic.LogisticRegression'>

# %%
print(model)
# Out:
# LogisticRegression(max_iter=3000, random_state=42)

# %%
from sklearn.pipeline import Pipeline

model_pipeline = Pipeline([
    ("tfidf", tfidf),
    ("classifier", best_model)
])

# %%
import joblib

joblib.dump(model_pipeline, "harmful_content_prediction_model.pkl")

print("Pipeline Saved Successfully!")
# Out:
# Pipeline Saved Successfully!

# %%
import joblib

model = joblib.load("harmful_content_prediction_model.pkl")

print("Model Loaded Successfully!")
# Out:
# Model Loaded Successfully!

# %%
print(model)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_features=10000, min_df=2,
#                                  ngram_range=(1, 2), stop_words='english')),
#                 ('classifier',
#                  LogisticRegression(max_iter=3000, random_state=42))])

# %%
print(model.named_steps)
# Out:
# {'tfidf': TfidfVectorizer(max_features=10000, min_df=2, ngram_range=(1, 2),
#                 stop_words='english'), 'classifier': LogisticRegression(max_iter=3000, random_state=42)}

# %%
print(model.named_steps["tfidf"])
# Out:
# TfidfVectorizer(max_features=10000, min_df=2, ngram_range=(1, 2),
#                 stop_words='english')

# %%
print(model.named_steps["classifier"])
# Out:
# LogisticRegression(max_iter=3000, random_state=42)

# %%
print(tfidf.max_features)
# Out:
# 10000

# %%
# %who
# Out:
# ConfusionMatrixDisplay	 DecisionTreeClassifier	 KNeighborsClassifier	 LabelEncoder	 LinearSVC	 LogisticRegression	 MultinomialNB	 Pipeline	 RandomForestClassifier
# TfidfVectorizer	 URL	 X	 X_test	 X_train	 accuracy	 accuracy_score	 ax	 best_model
# best_model_name	 classification_report	 cm	 comments	 comparison	 confusion_matrix	 connection_url	 create_engine	 cross_val_score
# df	 disp	 dt_model	 dt_pred	 encoder	 engine	 f1_score	 fig	 file
# final_dataset	 final_predictions	 gap	 harmful_df	 joblib	 label	 label_encoder	 lr_model	 lr_pred
# model	 model_pipeline	 models	 name	 nb_model	 nb_pred	 new_text	 new_vector	 np
# os	 output_file	 pd	 plt	 precision_score	 predicted_labels	 prediction	 prediction_df	 prediction_label
# predictions	 recall_score	 results	 rf_model	 rf_pred	 sample	 sample_text	 sample_vector	 scores
# status	 string	 svm_model	 svm_pred	 test_acc	 test_accuracy	 test_f1	 test_pred	 text
# texts	 tfidf	 tfidf_df	 train_acc	 train_accuracy	 train_f1	 train_pred	 train_test_split	 trained_models
# value	 vectorizer	 vectors	 y	 y_pred	 y_test	 y_train

# %%
# ==========================================
# Predict Single Text
# ==========================================

import joblib

# Load trained model
model = joblib.load("harmful_content_model.pkl")

# Load fitted TF-IDF vectorizer
vectorizer = joblib.load("tfidf_vectorizer.pkl")

# Load label encoder
label_encoder = joblib.load("label_encoder.pkl")

sample = [
    "I hate everyone in this group."
]

# Convert text to TF-IDF features
sample_vector = vectorizer.transform(sample)

# Predict
prediction = model.predict(sample_vector)

# Decode label
prediction = label_encoder.inverse_transform(prediction)

print("Input Text:")
print(sample[0])

print("\nPredicted Label:")
print(prediction[0])
# Out:
# Input Text:
# I hate everyone in this group.
#
# Predicted Label:
# NOT

# %%
samples = [
    "I hate everyone in this group.",
    "You are an idiot.",
    "I will kill you.",
    "Thank you very much.",
    "Have a nice day.",
    "I love my family.",
    "Go to hell.",
    "This government is doing a good job.",
    "You deserve respect.",
    "I will destroy everything."
]

sample_vectors = vectorizer.transform(samples)

predictions = model.predict(sample_vectors)

predicted_labels = label_encoder.inverse_transform(predictions)

import pandas as pd

result = pd.DataFrame({
    "Text": samples,
    "Prediction": predicted_labels
})

print(result)
# Out:
#                                    Text Prediction
# 0        I hate everyone in this group.        NOT
# 1                     You are an idiot.        HOF
# 2                      I will kill you.        HOF
# 3                  Thank you very much.        NOT
# 4                      Have a nice day.        NOT
# 5                     I love my family.        NOT
# 6                           Go to hell.        NOT
# 7  This government is doing a good job.        NOT
# 8                  You deserve respect.        NOT
# 9            I will destroy everything.        NOT

# %%
print(label_encoder.classes_)
# Out:
# ['HOF' 'NOT']

# %%
# ==========================================
# Predict Single Text
# ==========================================

import joblib

# Load trained model
model = joblib.load("harmful_content_model.pkl")

# Load fitted TF-IDF vectorizer
vectorizer = joblib.load("tfidf_vectorizer.pkl")

# Load label encoder
label_encoder = joblib.load("label_encoder.pkl")

sample = [
    "I hate everyone in this group."
]

# Convert text to TF-IDF features
sample_vector = vectorizer.transform(sample)

# Predict
prediction = model.predict(sample_vector)

# Decode label
prediction = label_encoder.inverse_transform(prediction)

print("Input Text:")
print(sample[0])

print("\nPredicted Label:")
print(prediction[0])
# Out:
# Input Text:
# I hate everyone in this group.
#
# Predicted Label:
# NOT

# %%
# ==========================================
# Predict Multiple Texts
# ==========================================

samples = [
    "I hate everyone in this group.",
    "You are an idiot.",
    "I will kill you.",
    "Thank you for your help.",
    "Have a wonderful day.",
    "Go to hell.",
    "I will destroy everything.",
    "You are amazing.",
    "I appreciate your support.",
    "You deserve respect."
]

# Convert text into TF-IDF features
sample_vectors = vectorizer.transform(samples)

# Predict
predictions = model.predict(sample_vectors)

# Convert encoded labels back to original labels
predictions = label_encoder.inverse_transform(predictions)

# Display results
for text, pred in zip(samples, predictions):
    print("Text :", text)
    print("Prediction :", pred)
    print("-" * 60)
# Out:
# Text : I hate everyone in this group.
# Prediction : NOT
# ------------------------------------------------------------
# Text : You are an idiot.
# Prediction : HOF
# ------------------------------------------------------------
# Text : I will kill you.
# Prediction : HOF
# ------------------------------------------------------------
# Text : Thank you for your help.
# Prediction : HOF
# ------------------------------------------------------------
# Text : Have a wonderful day.
# Prediction : NOT
# ------------------------------------------------------------
# Text : Go to hell.
# Prediction : NOT
# ------------------------------------------------------------
# Text : I will destroy everything.
# Prediction : NOT
# ------------------------------------------------------------
# Text : You are amazing.
# Prediction : NOT
# ------------------------------------------------------------
# Text : I appreciate your support.
# Prediction : NOT
# ------------------------------------------------------------
# Text : You deserve respect.
# Prediction : NOT
# ------------------------------------------------------------

# %%
# ==========================================
# Predict Class Probabilities
# ==========================================

sample = [
    "I hate everyone in this group."
]

# Convert text to TF-IDF features
sample_vector = vectorizer.transform(sample)

# Predict probabilities
prob = model.predict_proba(sample_vector)

print("Classes:", label_encoder.classes_)
print("Probabilities:", prob)
# Out:
# Classes: ['HOF' 'NOT']
# Probabilities: [[0.32042224 0.67957776]]

# %%
import joblib

# Load your Harmful Content model
model = joblib.load("harmful_content_model.pkl")

# Load vectorizer
vectorizer = joblib.load("tfidf_vectorizer.pkl")

# Load label encoder
label_encoder = joblib.load("label_encoder.pkl")

sample = [
    "I hate everyone in this group."
]

# Convert text to TF-IDF
sample_vector = vectorizer.transform(sample)

# Predict
prediction = model.predict(sample_vector)

# Convert numeric label to original label
prediction = label_encoder.inverse_transform(prediction)

print(prediction[0])
# Out:
# NOT

# %%
samples = [
    "I hate everyone in this group.",
    "I will kill you.",
    "Go to hell.",
    "Thank you for your help.",
    "Have a nice day."
]

sample_vector = vectorizer.transform(samples)

predictions = model.predict(sample_vector)

predictions = label_encoder.inverse_transform(predictions)

for text, pred in zip(samples, predictions):
    print(f"Text: {text}")
    print(f"Prediction: {pred}")
    print("-" * 50)
# Out:
# Text: I hate everyone in this group.
# Prediction: NOT
# --------------------------------------------------
# Text: I will kill you.
# Prediction: HOF
# --------------------------------------------------
# Text: Go to hell.
# Prediction: NOT
# --------------------------------------------------
# Text: Thank you for your help.
# Prediction: HOF
# --------------------------------------------------
# Text: Have a nice day.
# Prediction: NOT
# --------------------------------------------------

# %%
x
# Out:
# NOT

# %%
pip install streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: streamlit in c:\programdata\anaconda3\lib\site-packages (1.51.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (2.3.5)
# Requirement already satisfied: packaging<26,>=20 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (12.0.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (5.29.3)
# Requirement already satisfied: pyarrow<22,>=7.0 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (21.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (3.1.45)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\programdata\anaconda3\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\programdata\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\programdata\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.7.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\programdata\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\programdata\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kyatham chaitanya\appdata\roaming\python\python313\site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kyatham chaitanya\appdata\roaming\python\python313\site-packages (from requests<3,>=2.27->streamlit) (2026.2.25)
# Requirement already satisfied: attrs>=22.2.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.28.0)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Confusion Matrix Interpretation (Markdown)
#
# The confusion matrix compares the actual harmful content labels with the predicted labels generated by the selected machine learning model. The diagonal values represent correctly classified samples, while the off-diagonal values represent misclassified samples.
#
# A higher concentration of values along the diagonal indicates better classification performance. Any misclassifications may occur because some harmful and non-harmful comments share similar wording or context, making them difficult to distinguish.
#
# Overall, the confusion matrix provides a visual assessment of the model's performance and complements the classification report by highlighting the strengths and weaknesses of the classifier.

# %% [markdown]
# #### Save Final Model
#
# ## Objective
#
# Save the trained harmful content classification model, TF-IDF vectorizer, and Label Encoder for future prediction without retraining

# %% [markdown]
# #### Real-Time Harmful Content Prediction
# Objective
#
# A new social media comment is transformed using the saved TF-IDF Vectorizer and classified by the trained model to predict its harmful content label.

# %% [markdown]
# #### Final Conclusion
#
# #### Objective
#
# Summarize the overall performance of the harmful content detection model and justify the selection of the final classifier.

# %% [markdown]
# ====================================================
# ## HARMFUL CONTENT DETECTION PROJECT COMPLETED
# ====================================================
#
# ✓ Data Collection
# ✓ Exploratory Data Analysis (EDA)
# ✓ Data Preprocessing
# ✓ Feature Engineering (TF-IDF)
# ✓ Label Encoding
# ✓ Train-Test Split
# ✓ Model Building
# ✓ Model Comparison
# ✓ Best Model Selection
# ✓ Classification Report
# ✓ Confusion Matrix
# ✓ Cross Validation
# ✓ Save Model
# ✓ Load Model
# ✓ Real-Time Prediction

# %%
import joblib

# %%
model = joblib.load("harmful_content_prediction_model.pkl")

# %%
print(type(model))
# Out:
# <class 'sklearn.pipeline.Pipeline'>

# %%
print(model)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_features=10000, min_df=2,
#                                  ngram_range=(1, 2), stop_words='english')),
#                 ('classifier',
#                  LogisticRegression(max_iter=3000, random_state=42))])

# %%
import joblib

model = joblib.load("harmful_content_prediction_model.pkl")

print(model.named_steps)
# Out:
# {'tfidf': TfidfVectorizer(max_features=10000, min_df=2, ngram_range=(1, 2),
#                 stop_words='english'), 'classifier': LogisticRegression(max_iter=3000, random_state=42)}

# %%
# %who
# Out:
# LogisticRegression	 Pipeline	 TfidfVectorizer	 joblib	 label_encoder	 model	 pipeline	 sample

# %%
# ==========================================
#  Interactive Prediction System
# ==========================================

import joblib

# Load Model
model = joblib.load("harmful_content_prediction_model.pkl")

# Prediction Loop
while True:

    text = input("\nEnter a sentence (type 'exit' to stop): ")

    if text.lower() == "exit":
        print("Prediction System Closed.")
        break

    prediction = model.predict([text])

    print("Predicted Label :", prediction[0])
# Out:
# Enter a sentence (type 'exit' to stop):  8
# Predicted Label : 1
# Enter a sentence (type 'exit' to stop):  78
# Predicted Label : 1
# Enter a sentence (type 'exit' to stop):  78
# Predicted Label : 1
# Enter a sentence (type 'exit' to stop):  exit
# Prediction System Closed.

# %%
import joblib

# %%
model = joblib.load("harmful_content_prediction_model.pkl")

# %%
print(model)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.95, max_features=5000, min_df=2,
#                                  ngram_range=(1, 2), stop_words='english',
#                                  sublinear_tf=True)),
#                 ('classifier',
#                  LogisticRegression(max_iter=3000, random_state=42))])

# %%
sample = [
    "I hate everyone in this group."
]

prediction = model.predict(sample)

print(prediction)
# Out:
# [1]

# %%
samples = [
    "I hate everyone.",
    "You are stupid.",
    "Thank you very much.",
    "Have a nice day."
]

predictions = model.predict(samples)

for text, pred in zip(samples, predictions):
    print("Text :", text)
    print("Prediction :", pred)
    print("-"*40)
# Out:
# Text : I hate everyone.
# Prediction : 1
# ----------------------------------------
# Text : You are stupid.
# Prediction : 0
# ----------------------------------------
# Text : Thank you very much.
# Prediction : 1
# ----------------------------------------
# Text : Have a nice day.
# Prediction : 1
# ----------------------------------------

# %%
prob = model.predict_proba([
    "I hate everyone in this group."
])

print(prob)
# Out:
# [[0.39089795 0.60910205]]

# %%
exit()

# %%
import joblib

# Load the trained pipeline
model = joblib.load("harmful_content_prediction_model.pkl")

# Sample texts
samples = [
    "I hate everyone in this group.",
    "You are an idiot.",
    "Thank you for your help.",
    "Have a wonderful day.",
    "Go to hell.",
    "I appreciate your kindness."
]

# Predict
predictions = model.predict(samples)

# Display results
print("=" * 60)
print("HARMFUL CONTENT DETECTION")
print("=" * 60)

for text, pred in zip(samples, predictions):
    print(f"Text       : {text}")
    print(f"Prediction : {pred}")
    print("-" * 60)
# Out:
# ============================================================
# HARMFUL CONTENT DETECTION
# ============================================================
# Text       : I hate everyone in this group.
# Prediction : 1
# ------------------------------------------------------------
# Text       : You are an idiot.
# Prediction : 0
# ------------------------------------------------------------
# Text       : Thank you for your help.
# Prediction : 1
# ------------------------------------------------------------
# Text       : Have a wonderful day.
# Prediction : 1
# ------------------------------------------------------------
# Text       : Go to hell.
# Prediction : 1
# ------------------------------------------------------------
# Text       : I appreciate your kindness.
# Prediction : 1
# ------------------------------------------------------------
